# %%
# Program that requests and asks the user what operation to perform

import math
import numpy as np

print("Choose equation type:")
print("1. Quadratic (ax^2 + bx + c = 0)")
print("2. Cubic (ax^3 + bx^2 + cx + d = 0)")
print("3. Quartic (ax^4 + bx^3 + cx^2 + dx + e = 0)")

choice = int(input("Enter choice (1/2/3): "))

# Quadratic
if choice == 1:
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))
    
    discriminant = b**2 - 4*a*c
    
    if discriminant >= 0:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        print("Roots:", root1, root2)
    else:
        print("Complex roots")

# Cubic
elif choice == 2:
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))
    d = float(input("Enter d: "))
    
    roots = np.roots([a, b, c, d])
    print("Roots:", roots)

# Quartic
elif choice == 3:
    a = float(input("Enter a: "))
    b = float(input("Enter b: "))
    c = float(input("Enter c: "))
    d = float(input("Enter d: "))
    e = float(input("Enter e: "))
    
    roots = np.roots([a, b, c, d, e])
    print("Roots:", roots)

else:
    print("Invalid choice")
# Out:
# Choose equation type:
# 1. Quadratic (ax^2 + bx + c = 0)
# 2. Cubic (ax^3 + bx^2 + cx + d = 0)
# 3. Quartic (ax^4 + bx^3 + cx^2 + dx + e = 0)
# Enter choice (1/2/3):  1
# Enter a:  5
# Enter b:  6
# Enter c:  7
# Complex roots
