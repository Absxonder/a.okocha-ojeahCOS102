# %%
# Pseudocode for store checkout after purchase

from IPython.display import Image, display

display(Image(filename=r"C:\Users\HomePC\OneDrive\Pictures\pseudocode_checkout.jpg"))

# %%
# Flowchart for store checkout after purchase

from IPython.display import Image, display

display(Image(filename=r"C:\Users\HomePC\OneDrive\Pictures\flowchart_checkout.jpg"))

# %%
# Flowchart for typical day morning routine

from IPython.display import Image, display

display(Image(filename=r"C:\Users\HomePC\OneDrive\Pictures\flowchart_routine.jpg"))

# %%
# Algorithm that takes as input two names and their corresponding age and swaps it

# Pseudocode that takes as input two names and their corresponding age and swaps it

from IPython.display import Image, display

display(Image(filename=r"C:\Users\HomePC\OneDrive\Pictures\pseudocode_age_swap.jpg"))
